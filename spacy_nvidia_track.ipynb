# %% [markdown]
# # spaCy 2025 with NVIDIA Product Data — Exhaustive Tests
#
# This notebook exercises spaCy's latest pipelines on NVIDIA product descriptions.
# It compares **transformer** and **vector** models, tests **tokenization**, **POS**, **dependency parsing**, **NER**, **vector similarity**, and includes **performance benchmarking**.
#
# > If running in a restricted environment without internet access, the scraping step will fall back to a small, hardcoded list.

# %% [markdown]
# ## 1) Setup

# %%
# Install core dependencies (uncomment if needed)
# Note: If you're on a managed environment, installs may be restricted.
# !pip install -q spacy requests numpy beautifulsoup4

# Download spaCy models (comment out if already present)
# !python -m spacy download en_core_web_trf
# !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-trf==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.8.0/en_core_web_trf-3.8.0-py3-none-any.whl (457.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 3.7 MB/s eta 0:00:00
# Collecting spacy-curated-transformers<1.0.0,>=0.2.2 (from en-core-web-trf==3.8.0)
#   Downloading spacy_curated_transformers-0.3.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting curated-transformers<0.2.0,>=0.1.0 (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0)
#   Downloading curated_transformers-0.1.1-py2.py3-none-any.whl.metadata (965 bytes)
# Collecting curated-tokenizers<0.1.0,>=0.0.9 (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0)
#   Downloading curated_tokenizers-0.0.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: torch>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2.8.0+cu126)
# Requirement already satisfied: regex>=2022 in /usr/local/lib/python3.12/dist-packages (from curated-tokenizers<0.1.0,>=0.0.9->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2024.11.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.12.0->spacy-curated-transformers<1.0.0,>=0.2.2->en-core-web-trf==3.8.0) (3.0.3)
# Downloading spacy_curated_transformers-0.3.1-py2.py3-none-any.whl (237 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.9/237.9 kB 5.4 MB/s eta 0:00:00
# Downloading curated_tokenizers-0.0.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (734 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 734.0/734.0 kB 23.7 MB/s eta 0:00:00
# Downloading curated_transformers-0.1.1-py2.py3-none-any.whl (25 kB)
# Installing collected packages: curated-tokenizers, curated-transformers, spacy-curated-transformers, en-core-web-trf
# Successfully installed curated-tokenizers-0.0.9 curated-transformers-0.1.1 en-core-web-trf-3.8.0 spacy-curated-transformers-0.3.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Collecting en-core-web-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.8.0/en_core_web_md-3.8.0-py3-none-any.whl (33.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 53.7 MB/s eta 0:00:00
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# ## 2) Imports

# %%
import spacy, requests, time, numpy as np
from spacy.pipeline import EntityRuler
from spacy import displacy
from bs4 import BeautifulSoup

# %% [markdown]
# ## 3) Fetch NVIDIA Product Data (with fallback)

# %%
def fetch_nvidia_products(max_items=40):
    url = "https://www.nvidia.com/en-us/data-center/products/"
    try:
        resp = requests.get(url, timeout=15)
        resp.raise_for_status()
        soup = BeautifulSoup(resp.text, 'html.parser')
        # Simple heuristic: anchor texts that contain 'NVIDIA' and look like product names
        anchors = [a.get_text(strip=True) for a in soup.find_all('a')]
        products = [a for a in anchors if "NVIDIA" in a and len(a) <= 80]
        # Deduplicate and trim
        seen, deduped = set(), []
        for p in products:
            if p not in seen:
                seen.add(p)
                deduped.append(p)
        return deduped[:max_items] if deduped else None
    except Exception as e:
        print(f"[warn] Could not fetch live data: {e}")
        return None

nvidia_products = fetch_nvidia_products()
if not nvidia_products:
    nvidia_products = [
        "NVIDIA GeForce RTX 4090",
        "NVIDIA A100 Tensor Core GPU",
        "NVIDIA DGX H100 system",
        "NVIDIA HGX platform",
        "NVIDIA Blackwell architecture",
        "NVIDIA RTX 5090 Ti — upcoming GPU",
        "NVIDIA Grace Hopper Superchip",
        "NVIDIA DGX Station A100",
    ]

print(f"Loaded {len(nvidia_products)} product strings.")
for s in nvidia_products[:10]:
    print("•", s)
# Out:
# Loaded 37 product strings.
# • Artificial Intelligence Computing Leadership from NVIDIA
# • NVIDIA APIsExplore, test, and deploy AI models and agents
# • Private RegistryGuide for using NVIDIA NGC private registry with GPU cloud
# • NVIDIA NGCAccelerated, containerized AI models and SDKs
# • G-SYNC MonitorsSmooth, tear-free gaming with NVIDIA G-SYNC monitors
# • NVIDIA StudioHigh performance laptops and desktops, purpose-built for creators
# • NVIDIA AppOptimize gaming, streaming, and AI-powered creativity
# • NVIDIA RTX PRO DesktopsPowerful AI, graphics, rendering, and compute workloads
# • NVIDIA Mission Control
# • NVIDIA AI Enterprise Platform

# %% [markdown]
# ## 4) Load spaCy Models

# %%
# Heavy, accurate (Transformer-based) model
nlp_trf = spacy.load("en_core_web_trf")
# Lighter, fast model with word vectors
nlp_md  = spacy.load("en_core_web_md")

print("Transformer pipeline:", nlp_trf.pipe_names)
print("MD pipeline:", nlp_md.pipe_names)

# Vector existence checks
print("Has vector for 'GPU' (MD):", nlp_md.vocab["GPU"].has_vector)
print("Has vector for 'GPU' (TRF):", nlp_trf.vocab["GPU"].has_vector)
# Out:
# Transformer pipeline: ['transformer', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
# MD pipeline: ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
# Has vector for 'GPU' (MD): True
# Has vector for 'GPU' (TRF): False

# %% [markdown]
# ## 5) Add Custom Entity Rules (Domain Boost)

# %%
# Add simple patterns to help tag product-like spans
ruler = nlp_md.add_pipe("entity_ruler", before="ner")
patterns = [
    {"label": "PRODUCT", "pattern": [{"LOWER": "nvidia"}, {"IS_TITLE": True}]},
    {"label": "PRODUCT", "pattern": [{"LOWER": "dgx"}, {"IS_ALPHA": True}]},
    {"label": "PRODUCT", "pattern": [{"LOWER": "rtx"}, {"IS_DIGIT": True}]},
    {"label": "PRODUCT", "pattern": [{"LOWER": "blackwell"}]},
]
ruler.add_patterns(patterns)

# %% [markdown]
# ## 6) Analysis Helpers

# %%
def analyze_texts(nlp, texts):
    results = []
    for text in texts:
        doc = nlp(text)
        tokens = [(t.text, t.pos_, t.dep_) for t in doc]
        ents = [(e.text, e.label_) for e in doc.ents]
        # Similarity to the concept 'GPU' (may be None if vectors unavailable)
        sim_gpu = None
        try:
            sim_gpu = float(doc.similarity(nlp("GPU")))
        except Exception:
            pass
        results.append({
            "text": text,
            "tokens": tokens,
            "entities": ents,
            "similarity_to_GPU": sim_gpu
        })
    return results

def print_comparison(res_md, res_trf, products):
    for i, txt in enumerate(products):
        print("TEXT:", txt)
        print("  MD  ents:", res_md[i]["entities"])
        print("  TRF ents:", res_trf[i]["entities"])
        print("  MD  sim(GPU):", res_md[i]["similarity_to_GPU"])
        print("  TRF sim(GPU):", res_trf[i]["similarity_to_GPU"])
        print("-"*60)

# %% [markdown]
# ## 7) Run Tests (NER, Similarity)

# %%
res_md  = analyze_texts(nlp_md,  nvidia_products)
res_trf = analyze_texts(nlp_trf, nvidia_products)
print_comparison(res_md, res_trf, nvidia_products[:20])
# Out:
# /tmp/ipython-input-4148868788.py:10: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   sim_gpu = float(doc.similarity(nlp("GPU")))
# /tmp/ipython-input-4148868788.py:10: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   sim_gpu = float(doc.similarity(nlp("GPU")))
# TEXT: Artificial Intelligence Computing Leadership from NVIDIA
#   MD  ents: [('NVIDIA', 'ORG')]
#   TRF ents: [('NVIDIA', 'ORG')]
#   MD  sim(GPU): 0.304282009601593
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: NVIDIA APIsExplore, test, and deploy AI models and agents
#   MD  ents: [('NVIDIA', 'ORG'), ('AI', 'ORG')]
#   TRF ents: [('NVIDIA', 'ORG')]
#   MD  sim(GPU): 0.3404432535171509
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: Private RegistryGuide for using NVIDIA NGC private registry with GPU cloud
#   MD  ents: [('NVIDIA', 'ORG'), ('GPU', 'ORG')]
#   TRF ents: [('NVIDIA NGC', 'ORG')]
#   MD  sim(GPU): 0.4650319218635559
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: NVIDIA NGCAccelerated, containerized AI models and SDKs
#   MD  ents: [('NVIDIA NGCAccelerated', 'NORP')]
#   TRF ents: [('NVIDIA', 'ORG')]
#   MD  sim(GPU): 0.446361780166626
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: G-SYNC MonitorsSmooth, tear-free gaming with NVIDIA G-SYNC monitors
#   MD  ents: [('NVIDIA G', 'PRODUCT')]
#   TRF ents: [('G-SYNC', 'PRODUCT'), ('NVIDIA', 'ORG'), ('G-SYNC', 'PRODUCT')]
#   MD  sim(GPU): 0.4279080033302307
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: NVIDIA StudioHigh performance laptops and desktops, purpose-built for creators
#   MD  ents: [('NVIDIA', 'ORG')]
#   TRF ents: [('NVIDIA', 'ORG'), ('StudioHigh', 'PRODUCT')]
#   MD  sim(GPU): 0.4128357768058777
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: NVIDIA AppOptimize gaming, streaming, and AI-powered creativity
#   MD  ents: [('NVIDIA', 'ORG')]
#   TRF ents: [('NVIDIA', 'ORG')]
#   MD  sim(GPU): 0.3619914948940277
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: NVIDIA RTX PRO DesktopsPowerful AI, graphics, rendering, and compute workloads
#   MD  ents: []
#   TRF ents: [('NVIDIA', 'ORG'), ('RTX PRO', 'PRODUCT')]
#   MD  sim(GPU): 0.4786291718482971
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: NVIDIA Mission Control
#   MD  ents: [('NVIDIA Mission', 'PRODUCT')]
#   TRF ents: [('NVIDIA', 'ORG')]
#   MD  sim(GPU): 0.45463332533836365
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: NVIDIA AI Enterprise Platform
#   MD  ents: [('NVIDIA AI Enterprise Platform', 'ORG')]
#   TRF ents: [('NVIDIA', 'ORG')]
#   MD  sim(GPU): 0.392866313457489
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: NVIDIA Run:ai
#   MD  ents: [('NVIDIA Run', 'PRODUCT')]
#   TRF ents: [('NVIDIA', 'ORG')]
#   MD  sim(GPU): 0.5120177268981934
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: AI WorkbenchSimplify AI development with NVIDIA AI Workbench on GPUs
#   MD  ents: [('NVIDIA AI Workbench', 'ORG')]
#   TRF ents: [('NVIDIA', 'ORG')]
#   MD  sim(GPU): 0.4344157576560974
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: API CatalogExplore NVIDIA's AI models, blueprints, and tools for developers
#   MD  ents: [('NVIDIA', 'ORG'), ('AI', 'ORG')]
#   TRF ents: [('NVIDIA', 'ORG')]
#   MD  sim(GPU): 0.43463900685310364
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: NsightExplore NVIDIA developer tools for AI, graphics, and HPC
#   MD  ents: [('NVIDIA', 'ORG'), ('HPC', 'ORG')]
#   TRF ents: [('NsightExplore', 'ORG'), ('NVIDIA', 'ORG')]
#   MD  sim(GPU): 0.3996241092681885
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: NVIDIA App for LaptopsOptimize enterprise GPU management
#   MD  ents: [('NVIDIA App', 'PRODUCT'), ('LaptopsOptimize', 'ORG'), ('GPU', 'ORG')]
#   TRF ents: [('NVIDIA', 'ORG')]
#   MD  sim(GPU): 0.6615325808525085
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: NVIDIA NGCAccelerate AI and HPC workloads with NVIDIA GPU Cloud solutions
#   MD  ents: [('NVIDIA', 'ORG'), ('HPC', 'ORG'), ('NVIDIA', 'ORG')]
#   TRF ents: [('NVIDIA', 'ORG'), ('NVIDIA', 'ORG')]
#   MD  sim(GPU): 0.6331314444541931
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: OverviewPowering AI, HPC, and modern workloads with NVIDIA
#   MD  ents: [('OverviewPowering AI', 'ORG'), ('HPC', 'ORG'), ('NVIDIA', 'ORG')]
#   TRF ents: [('NVIDIA', 'ORG')]
#   MD  sim(GPU): 0.38825684785842896
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: VirtualizationNVIDIA virtual GPU software delivers powerful GPU performance
#   MD  ents: [('GPU', 'ORG'), ('GPU', 'ORG')]
#   TRF ents: [('VirtualizationNVIDIA', 'ORG')]
#   MD  sim(GPU): 0.7406839728355408
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: NVIDIA Cloud Partners
#   MD  ents: [('NVIDIA Cloud', 'PRODUCT')]
#   TRF ents: [('NVIDIA Cloud Partners', 'ORG')]
#   MD  sim(GPU): 0.40508323907852173
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------
# TEXT: NVIDIA GB300 NVL72
#   MD  ents: [('NVIDIA GB300', 'ORG')]
#   TRF ents: [('NVIDIA', 'ORG'), ('GB300', 'PRODUCT'), ('NVL72', 'PRODUCT')]
#   MD  sim(GPU): 0.6713147163391113
#   TRF sim(GPU): 0.0
# ------------------------------------------------------------

# %% [markdown]
# ## 8) Performance Benchmark

# %%
def time_pipeline(nlp, texts, reps=50):
    start = time.time()
    for _ in range(reps):
        for t in texts:
            _ = nlp(t)
    return round((time.time() - start) / reps, 4)

print("MD  avg sec/rep:", time_pipeline(nlp_md,  nvidia_products))
print("TRF avg sec/rep:", time_pipeline(nlp_trf, nvidia_products))
# Out:
# MD  avg sec/rep: 0.2534
# TRF avg sec/rep: 3.2063

# %% [markdown]
# ## 9) Visualization (Dependency Parse)

# %%
doc = nlp_trf("NVIDIA DGX H100 system accelerates training workloads.")
displacy.render(doc, style="dep", jupyter=True, options={"distance": 110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8b385a2a00214912bb26718cc4d241f8-0" class="displacy" width="820" height="247.0" direction="ltr" style="max-width: none; height: 247.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">NVIDIA</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">DGX</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">H100</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">system</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">accelerates</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">training</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">workloads.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8b385a2a00214912bb26718cc4d241f8-0-0" stroke-width="2px" d="M70,112.0 C70,2.0 380.0,2.0 380.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8b385a2a00214912bb26718cc4d241f8-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,114.0 L62,102.0 78,102.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8b385a2a00214912bb26718cc4d241f8-0-1" stroke-width="2px" d="M180,112.0 C180,57.0 265.0,57.0 265.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8b385a2a00214912bb26718cc4d241f8-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,114.0 L172,102.0 188,102.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8b385a2a00214912bb26718cc4d241f8-0-2" stroke-width="2px" d="M290,112.0 C290,57.0 375.0,57.0 375.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8b385a2a00214912bb26718cc4d241f8-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,114.0 L282,102.0 298,102.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8b385a2a00214912bb26718cc4d241f8-0-3" stroke-width="2px" d="M400,112.0 C400,57.0 485.0,57.0 485.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8b385a2a00214912bb26718cc4d241f8-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,114.0 L392,102.0 408,102.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8b385a2a00214912bb26718cc4d241f8-0-4" stroke-width="2px" d="M620,112.0 C620,57.0 705.0,57.0 705.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8b385a2a00214912bb26718cc4d241f8-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M620,114.0 L612,102.0 628,102.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8b385a2a00214912bb26718cc4d241f8-0-5" stroke-width="2px" d="M510,112.0 C510,2.0 710.0,2.0 710.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8b385a2a00214912bb26718cc4d241f8-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M710.0,114.0 L718.0,102.0 702.0,102.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ## 10) Optional: Similarity Clustering (vectors)

# %%
# Uses MD model vectors to compute pairwise cosine similarity.
# For larger corpora, consider FAISS or a vector DB.
def cosine(a, b):
    return float(np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b)))

vectors = [nlp_md(t).vector for t in nvidia_products]
for i in range(len(nvidia_products)):
    for j in range(i+1, len(nvidia_products)):
        print(f"Sim({nvidia_products[i][:30]}..., {nvidia_products[j][:30]}...) =",
              round(cosine(vectors[i], vectors[j]), 4))
# Out:
# Sim(Artificial Intelligence Comput..., NVIDIA APIsExplore, test, and ...) = 0.734
# Sim(Artificial Intelligence Comput..., Private RegistryGuide for usin...) = 0.7287
# Sim(Artificial Intelligence Comput..., NVIDIA NGCAccelerated, contain...) = 0.6363
# Sim(Artificial Intelligence Comput..., G-SYNC MonitorsSmooth, tear-fr...) = 0.5171
# Sim(Artificial Intelligence Comput..., NVIDIA StudioHigh performance ...) = 0.7271
# Sim(Artificial Intelligence Comput..., NVIDIA AppOptimize gaming, str...) = 0.6897
# Sim(Artificial Intelligence Comput..., NVIDIA RTX PRO DesktopsPowerfu...) = 0.5805
# Sim(Artificial Intelligence Comput..., NVIDIA Mission Control...) = 0.8269
# Sim(Artificial Intelligence Comput..., NVIDIA AI Enterprise Platform...) = 0.695
# Sim(Artificial Intelligence Comput..., NVIDIA Run:ai...) = 0.5025
# Sim(Artificial Intelligence Comput..., AI WorkbenchSimplify AI develo...) = 0.5691
# Sim(Artificial Intelligence Comput..., API CatalogExplore NVIDIA's AI...) = 0.7635
# Sim(Artificial Intelligence Comput..., NsightExplore NVIDIA developer...) = 0.6637
# Sim(Artificial Intelligence Comput..., NVIDIA App for LaptopsOptimize...) = 0.6494
# Sim(Artificial Intelligence Comput..., NVIDIA NGCAccelerate AI and HP...) = 0.7255
# Sim(Artificial Intelligence Comput..., OverviewPowering AI, HPC, and ...) = 0.6257
# Sim(Artificial Intelligence Comput..., VirtualizationNVIDIA virtual G...) = 0.6982
# Sim(Artificial Intelligence Comput..., NVIDIA Cloud Partners...) = 0.7208
# Sim(Artificial Intelligence Comput..., NVIDIA GB300 NVL72...) = 0.5107
# Sim(Artificial Intelligence Comput..., NVIDIA GB200 NVL72...) = 0.5107
# Sim(Artificial Intelligence Comput..., NVIDIA-Certified Systems...) = 0.7048
# Sim(Artificial Intelligence Comput..., NVIDIA Blackwell Architecture...) = 0.678
# Sim(Artificial Intelligence Comput..., NVIDIA Hopper Architecture...) = 0.6099
# Sim(Artificial Intelligence Comput..., NVIDIA Ada Lovelace Architectu...) = 0.5487
# Sim(Artificial Intelligence Comput..., NVIDIA Data Center Corporate B...) = 0.7411
# Sim(Artificial Intelligence Comput..., NVIDIA Data Center Technical B...) = 0.7694
# Sim(Artificial Intelligence Comput..., NVIDIA AI Enterprise...) = 0.6776
# Sim(Artificial Intelligence Comput..., NVIDIA NGC...) = 0.2269
# Sim(Artificial Intelligence Comput..., NVIDIA® accelerated computing ...) = 0.815
# Sim(Artificial Intelligence Comput..., NVIDIA Quantum InfiniBand...) = 0.4804
# Sim(Artificial Intelligence Comput..., NVIDIA Spectrum™-X Ethernet...) = 0.6177
# Sim(Artificial Intelligence Comput..., NVIDIA NGC™...) = 0.3821
# Sim(Artificial Intelligence Comput..., NVIDIA-Certified Systems for E...) = 0.7435
# Sim(Artificial Intelligence Comput..., NVIDIA DGX Platform...) = 0.4909
# Sim(Artificial Intelligence Comput..., NVIDIA HGX Platform...) = 0.6969
# Sim(Artificial Intelligence Comput..., NVIDIA Foundation...) = 0.6141
# Sim(NVIDIA APIsExplore, test, and ..., Private RegistryGuide for usin...) = 0.7132
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA NGCAccelerated, contain...) = 0.7937
# Sim(NVIDIA APIsExplore, test, and ..., G-SYNC MonitorsSmooth, tear-fr...) = 0.628
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA StudioHigh performance ...) = 0.7913
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA AppOptimize gaming, str...) = 0.8875
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA RTX PRO DesktopsPowerfu...) = 0.8012
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA Mission Control...) = 0.6751
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA AI Enterprise Platform...) = 0.7279
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA Run:ai...) = 0.7253
# Sim(NVIDIA APIsExplore, test, and ..., AI WorkbenchSimplify AI develo...) = 0.7614
# Sim(NVIDIA APIsExplore, test, and ..., API CatalogExplore NVIDIA's AI...) = 0.9295
# Sim(NVIDIA APIsExplore, test, and ..., NsightExplore NVIDIA developer...) = 0.8719
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA App for LaptopsOptimize...) = 0.645
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA NGCAccelerate AI and HP...) = 0.7847
# Sim(NVIDIA APIsExplore, test, and ..., OverviewPowering AI, HPC, and ...) = 0.8656
# Sim(NVIDIA APIsExplore, test, and ..., VirtualizationNVIDIA virtual G...) = 0.6357
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA Cloud Partners...) = 0.6246
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA GB300 NVL72...) = 0.4371
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA GB200 NVL72...) = 0.4371
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA-Certified Systems...) = 0.6059
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA Blackwell Architecture...) = 0.5695
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA Hopper Architecture...) = 0.4498
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA Ada Lovelace Architectu...) = 0.4487
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA Data Center Corporate B...) = 0.703
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA Data Center Technical B...) = 0.6993
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA AI Enterprise...) = 0.7638
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA NGC...) = 0.1585
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA® accelerated computing ...) = 0.6758
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA Quantum InfiniBand...) = 0.3587
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA Spectrum™-X Ethernet...) = 0.5528
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA NGC™...) = 0.2895
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA-Certified Systems for E...) = 0.6812
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA DGX Platform...) = 0.3824
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA HGX Platform...) = 0.5954
# Sim(NVIDIA APIsExplore, test, and ..., NVIDIA Foundation...) = 0.5947
# Sim(Private RegistryGuide for usin..., NVIDIA NGCAccelerated, contain...) = 0.6458
# Sim(Private RegistryGuide for usin..., G-SYNC MonitorsSmooth, tear-fr...) = 0.5846
# Sim(Private RegistryGuide for usin..., NVIDIA StudioHigh performance ...) = 0.6978
# Sim(Private RegistryGuide for usin..., NVIDIA AppOptimize gaming, str...) = 0.67
# Sim(Private RegistryGuide for usin..., NVIDIA RTX PRO DesktopsPowerfu...) = 0.6271
# Sim(Private RegistryGuide for usin..., NVIDIA Mission Control...) = 0.6815
# Sim(Private RegistryGuide for usin..., NVIDIA AI Enterprise Platform...) = 0.7508
# Sim(Private RegistryGuide for usin..., NVIDIA Run:ai...) = 0.522
# Sim(Private RegistryGuide for usin..., AI WorkbenchSimplify AI develo...) = 0.5789
# Sim(Private RegistryGuide for usin..., API CatalogExplore NVIDIA's AI...) = 0.7799
# Sim(Private RegistryGuide for usin..., NsightExplore NVIDIA developer...) = 0.7121
# Sim(Private RegistryGuide for usin..., NVIDIA App for LaptopsOptimize...) = 0.8048
# Sim(Private RegistryGuide for usin..., NVIDIA NGCAccelerate AI and HP...) = 0.7847
# Sim(Private RegistryGuide for usin..., OverviewPowering AI, HPC, and ...) = 0.613
# Sim(Private RegistryGuide for usin..., VirtualizationNVIDIA virtual G...) = 0.723
# Sim(Private RegistryGuide for usin..., NVIDIA Cloud Partners...) = 0.7682
# Sim(Private RegistryGuide for usin..., NVIDIA GB300 NVL72...) = 0.5209
# Sim(Private RegistryGuide for usin..., NVIDIA GB200 NVL72...) = 0.5209
# Sim(Private RegistryGuide for usin..., NVIDIA-Certified Systems...) = 0.6733
# Sim(Private RegistryGuide for usin..., NVIDIA Blackwell Architecture...) = 0.659
# Sim(Private RegistryGuide for usin..., NVIDIA Hopper Architecture...) = 0.5252
# Sim(Private RegistryGuide for usin..., NVIDIA Ada Lovelace Architectu...) = 0.4853
# Sim(Private RegistryGuide for usin..., NVIDIA Data Center Corporate B...) = 0.7571
# Sim(Private RegistryGuide for usin..., NVIDIA Data Center Technical B...) = 0.7659
# Sim(Private RegistryGuide for usin..., NVIDIA AI Enterprise...) = 0.7146
# Sim(Private RegistryGuide for usin..., NVIDIA NGC...) = 0.4969
# Sim(Private RegistryGuide for usin..., NVIDIA® accelerated computing ...) = 0.7763
# Sim(Private RegistryGuide for usin..., NVIDIA Quantum InfiniBand...) = 0.4392
# Sim(Private RegistryGuide for usin..., NVIDIA Spectrum™-X Ethernet...) = 0.6389
# Sim(Private RegistryGuide for usin..., NVIDIA NGC™...) = 0.616
# Sim(Private RegistryGuide for usin..., NVIDIA-Certified Systems for E...) = 0.7756
# Sim(Private RegistryGuide for usin..., NVIDIA DGX Platform...) = 0.5496
# Sim(Private RegistryGuide for usin..., NVIDIA HGX Platform...) = 0.7541
# Sim(Private RegistryGuide for usin..., NVIDIA Foundation...) = 0.628
# Sim(NVIDIA NGCAccelerated, contain..., G-SYNC MonitorsSmooth, tear-fr...) = 0.6215
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA StudioHigh performance ...) = 0.7223
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA AppOptimize gaming, str...) = 0.7828
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA RTX PRO DesktopsPowerfu...) = 0.7517
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA Mission Control...) = 0.6651
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA AI Enterprise Platform...) = 0.6689
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA Run:ai...) = 0.6874
# Sim(NVIDIA NGCAccelerated, contain..., AI WorkbenchSimplify AI develo...) = 0.7542
# Sim(NVIDIA NGCAccelerated, contain..., API CatalogExplore NVIDIA's AI...) = 0.7992
# Sim(NVIDIA NGCAccelerated, contain..., NsightExplore NVIDIA developer...) = 0.7865
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA App for LaptopsOptimize...) = 0.6262
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA NGCAccelerate AI and HP...) = 0.7653
# Sim(NVIDIA NGCAccelerated, contain..., OverviewPowering AI, HPC, and ...) = 0.7932
# Sim(NVIDIA NGCAccelerated, contain..., VirtualizationNVIDIA virtual G...) = 0.6397
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA Cloud Partners...) = 0.5597
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA GB300 NVL72...) = 0.5208
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA GB200 NVL72...) = 0.5208
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA-Certified Systems...) = 0.5724
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA Blackwell Architecture...) = 0.6193
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA Hopper Architecture...) = 0.5693
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA Ada Lovelace Architectu...) = 0.4842
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA Data Center Corporate B...) = 0.5701
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA Data Center Technical B...) = 0.5829
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA AI Enterprise...) = 0.7413
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA NGC...) = 0.3114
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA® accelerated computing ...) = 0.594
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA Quantum InfiniBand...) = 0.4423
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA Spectrum™-X Ethernet...) = 0.5081
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA NGC™...) = 0.4029
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA-Certified Systems for E...) = 0.5902
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA DGX Platform...) = 0.4573
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA HGX Platform...) = 0.5774
# Sim(NVIDIA NGCAccelerated, contain..., NVIDIA Foundation...) = 0.5796
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA StudioHigh performance ...) = 0.6402
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA AppOptimize gaming, str...) = 0.7126
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA RTX PRO DesktopsPowerfu...) = 0.6115
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA Mission Control...) = 0.5429
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA AI Enterprise Platform...) = 0.6076
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA Run:ai...) = 0.6928
# Sim(G-SYNC MonitorsSmooth, tear-fr..., AI WorkbenchSimplify AI develo...) = 0.6083
# Sim(G-SYNC MonitorsSmooth, tear-fr..., API CatalogExplore NVIDIA's AI...) = 0.6835
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NsightExplore NVIDIA developer...) = 0.6457
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA App for LaptopsOptimize...) = 0.5868
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA NGCAccelerate AI and HP...) = 0.6524
# Sim(G-SYNC MonitorsSmooth, tear-fr..., OverviewPowering AI, HPC, and ...) = 0.5916
# Sim(G-SYNC MonitorsSmooth, tear-fr..., VirtualizationNVIDIA virtual G...) = 0.5445
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA Cloud Partners...) = 0.5406
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA GB300 NVL72...) = 0.5285
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA GB200 NVL72...) = 0.5285
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA-Certified Systems...) = 0.688
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA Blackwell Architecture...) = 0.5445
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA Hopper Architecture...) = 0.4069
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA Ada Lovelace Architectu...) = 0.4687
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA Data Center Corporate B...) = 0.5213
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA Data Center Technical B...) = 0.5527
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA AI Enterprise...) = 0.6672
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA NGC...) = 0.2584
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA® accelerated computing ...) = 0.5118
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA Quantum InfiniBand...) = 0.4252
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA Spectrum™-X Ethernet...) = 0.4519
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA NGC™...) = 0.3062
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA-Certified Systems for E...) = 0.654
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA DGX Platform...) = 0.4055
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA HGX Platform...) = 0.5696
# Sim(G-SYNC MonitorsSmooth, tear-fr..., NVIDIA Foundation...) = 0.5424
# Sim(NVIDIA StudioHigh performance ..., NVIDIA AppOptimize gaming, str...) = 0.7473
# Sim(NVIDIA StudioHigh performance ..., NVIDIA RTX PRO DesktopsPowerfu...) = 0.6498
# Sim(NVIDIA StudioHigh performance ..., NVIDIA Mission Control...) = 0.699
# Sim(NVIDIA StudioHigh performance ..., NVIDIA AI Enterprise Platform...) = 0.6752
# Sim(NVIDIA StudioHigh performance ..., NVIDIA Run:ai...) = 0.5879
# Sim(NVIDIA StudioHigh performance ..., AI WorkbenchSimplify AI develo...) = 0.6327
# Sim(NVIDIA StudioHigh performance ..., API CatalogExplore NVIDIA's AI...) = 0.8108
# Sim(NVIDIA StudioHigh performance ..., NsightExplore NVIDIA developer...) = 0.7445
# Sim(NVIDIA StudioHigh performance ..., NVIDIA App for LaptopsOptimize...) = 0.7151
# Sim(NVIDIA StudioHigh performance ..., NVIDIA NGCAccelerate AI and HP...) = 0.7555
# Sim(NVIDIA StudioHigh performance ..., OverviewPowering AI, HPC, and ...) = 0.7218
# Sim(NVIDIA StudioHigh performance ..., VirtualizationNVIDIA virtual G...) = 0.6832
# Sim(NVIDIA StudioHigh performance ..., NVIDIA Cloud Partners...) = 0.6265
# Sim(NVIDIA StudioHigh performance ..., NVIDIA GB300 NVL72...) = 0.5158
# Sim(NVIDIA StudioHigh performance ..., NVIDIA GB200 NVL72...) = 0.5158
# Sim(NVIDIA StudioHigh performance ..., NVIDIA-Certified Systems...) = 0.6392
# Sim(NVIDIA StudioHigh performance ..., NVIDIA Blackwell Architecture...) = 0.5764
# Sim(NVIDIA StudioHigh performance ..., NVIDIA Hopper Architecture...) = 0.4938
# Sim(NVIDIA StudioHigh performance ..., NVIDIA Ada Lovelace Architectu...) = 0.4558
# Sim(NVIDIA StudioHigh performance ..., NVIDIA Data Center Corporate B...) = 0.6663
# Sim(NVIDIA StudioHigh performance ..., NVIDIA Data Center Technical B...) = 0.6925
# Sim(NVIDIA StudioHigh performance ..., NVIDIA AI Enterprise...) = 0.6904
# Sim(NVIDIA StudioHigh performance ..., NVIDIA NGC...) = 0.2323
# Sim(NVIDIA StudioHigh performance ..., NVIDIA® accelerated computing ...) = 0.7192
# Sim(NVIDIA StudioHigh performance ..., NVIDIA Quantum InfiniBand...) = 0.4068
# Sim(NVIDIA StudioHigh performance ..., NVIDIA Spectrum™-X Ethernet...) = 0.5938
# Sim(NVIDIA StudioHigh performance ..., NVIDIA NGC™...) = 0.3695
# Sim(NVIDIA StudioHigh performance ..., NVIDIA-Certified Systems for E...) = 0.739
# Sim(NVIDIA StudioHigh performance ..., NVIDIA DGX Platform...) = 0.4619
# Sim(NVIDIA StudioHigh performance ..., NVIDIA HGX Platform...) = 0.6495
# Sim(NVIDIA StudioHigh performance ..., NVIDIA Foundation...) = 0.6293
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA RTX PRO DesktopsPowerfu...) = 0.7767
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA Mission Control...) = 0.671
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA AI Enterprise Platform...) = 0.7173
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA Run:ai...) = 0.7754
# Sim(NVIDIA AppOptimize gaming, str..., AI WorkbenchSimplify AI develo...) = 0.7642
# Sim(NVIDIA AppOptimize gaming, str..., API CatalogExplore NVIDIA's AI...) = 0.8748
# Sim(NVIDIA AppOptimize gaming, str..., NsightExplore NVIDIA developer...) = 0.8459
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA App for LaptopsOptimize...) = 0.6177
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA NGCAccelerate AI and HP...) = 0.7377
# Sim(NVIDIA AppOptimize gaming, str..., OverviewPowering AI, HPC, and ...) = 0.8163
# Sim(NVIDIA AppOptimize gaming, str..., VirtualizationNVIDIA virtual G...) = 0.641
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA Cloud Partners...) = 0.6134
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA GB300 NVL72...) = 0.4663
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA GB200 NVL72...) = 0.4663
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA-Certified Systems...) = 0.6789
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA Blackwell Architecture...) = 0.5768
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA Hopper Architecture...) = 0.4638
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA Ada Lovelace Architectu...) = 0.4785
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA Data Center Corporate B...) = 0.625
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA Data Center Technical B...) = 0.6153
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA AI Enterprise...) = 0.781
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA NGC...) = 0.2134
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA® accelerated computing ...) = 0.5983
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA Quantum InfiniBand...) = 0.3304
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA Spectrum™-X Ethernet...) = 0.4923
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA NGC™...) = 0.2954
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA-Certified Systems for E...) = 0.7006
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA DGX Platform...) = 0.3745
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA HGX Platform...) = 0.5749
# Sim(NVIDIA AppOptimize gaming, str..., NVIDIA Foundation...) = 0.5855
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA Mission Control...) = 0.5625
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA AI Enterprise Platform...) = 0.6205
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA Run:ai...) = 0.7471
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., AI WorkbenchSimplify AI develo...) = 0.718
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., API CatalogExplore NVIDIA's AI...) = 0.8337
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NsightExplore NVIDIA developer...) = 0.8825
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA App for LaptopsOptimize...) = 0.6308
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA NGCAccelerate AI and HP...) = 0.751
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., OverviewPowering AI, HPC, and ...) = 0.8411
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., VirtualizationNVIDIA virtual G...) = 0.5975
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA Cloud Partners...) = 0.5211
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA GB300 NVL72...) = 0.5183
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA GB200 NVL72...) = 0.5183
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA-Certified Systems...) = 0.5054
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA Blackwell Architecture...) = 0.5532
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA Hopper Architecture...) = 0.4459
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA Ada Lovelace Architectu...) = 0.4328
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA Data Center Corporate B...) = 0.6065
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA Data Center Technical B...) = 0.5877
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA AI Enterprise...) = 0.7096
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA NGC...) = 0.2655
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA® accelerated computing ...) = 0.4866
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA Quantum InfiniBand...) = 0.4037
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA Spectrum™-X Ethernet...) = 0.4968
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA NGC™...) = 0.3336
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA-Certified Systems for E...) = 0.5597
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA DGX Platform...) = 0.3585
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA HGX Platform...) = 0.5316
# Sim(NVIDIA RTX PRO DesktopsPowerfu..., NVIDIA Foundation...) = 0.5603
# Sim(NVIDIA Mission Control..., NVIDIA AI Enterprise Platform...) = 0.7263
# Sim(NVIDIA Mission Control..., NVIDIA Run:ai...) = 0.5612
# Sim(NVIDIA Mission Control..., AI WorkbenchSimplify AI develo...) = 0.5829
# Sim(NVIDIA Mission Control..., API CatalogExplore NVIDIA's AI...) = 0.732
# Sim(NVIDIA Mission Control..., NsightExplore NVIDIA developer...) = 0.6219
# Sim(NVIDIA Mission Control..., NVIDIA App for LaptopsOptimize...) = 0.6914
# Sim(NVIDIA Mission Control..., NVIDIA NGCAccelerate AI and HP...) = 0.7539
# Sim(NVIDIA Mission Control..., OverviewPowering AI, HPC, and ...) = 0.5893
# Sim(NVIDIA Mission Control..., VirtualizationNVIDIA virtual G...) = 0.7257
# Sim(NVIDIA Mission Control..., NVIDIA Cloud Partners...) = 0.74
# Sim(NVIDIA Mission Control..., NVIDIA GB300 NVL72...) = 0.6547
# Sim(NVIDIA Mission Control..., NVIDIA GB200 NVL72...) = 0.6547
# Sim(NVIDIA Mission Control..., NVIDIA-Certified Systems...) = 0.7391
# Sim(NVIDIA Mission Control..., NVIDIA Blackwell Architecture...) = 0.7629
# Sim(NVIDIA Mission Control..., NVIDIA Hopper Architecture...) = 0.6918
# Sim(NVIDIA Mission Control..., NVIDIA Ada Lovelace Architectu...) = 0.6508
# Sim(NVIDIA Mission Control..., NVIDIA Data Center Corporate B...) = 0.6369
# Sim(NVIDIA Mission Control..., NVIDIA Data Center Technical B...) = 0.6876
# Sim(NVIDIA Mission Control..., NVIDIA AI Enterprise...) = 0.7464
# Sim(NVIDIA Mission Control..., NVIDIA NGC...) = 0.3044
# Sim(NVIDIA Mission Control..., NVIDIA® accelerated computing ...) = 0.7699
# Sim(NVIDIA Mission Control..., NVIDIA Quantum InfiniBand...) = 0.5492
# Sim(NVIDIA Mission Control..., NVIDIA Spectrum™-X Ethernet...) = 0.6244
# Sim(NVIDIA Mission Control..., NVIDIA NGC™...) = 0.4231
# Sim(NVIDIA Mission Control..., NVIDIA-Certified Systems for E...) = 0.7079
# Sim(NVIDIA Mission Control..., NVIDIA DGX Platform...) = 0.5579
# Sim(NVIDIA Mission Control..., NVIDIA HGX Platform...) = 0.7611
# Sim(NVIDIA Mission Control..., NVIDIA Foundation...) = 0.6737
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA Run:ai...) = 0.6276
# Sim(NVIDIA AI Enterprise Platform..., AI WorkbenchSimplify AI develo...) = 0.6765
# Sim(NVIDIA AI Enterprise Platform..., API CatalogExplore NVIDIA's AI...) = 0.7781
# Sim(NVIDIA AI Enterprise Platform..., NsightExplore NVIDIA developer...) = 0.7059
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA App for LaptopsOptimize...) = 0.7925
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA NGCAccelerate AI and HP...) = 0.8529
# Sim(NVIDIA AI Enterprise Platform..., OverviewPowering AI, HPC, and ...) = 0.6225
# Sim(NVIDIA AI Enterprise Platform..., VirtualizationNVIDIA virtual G...) = 0.6759
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA Cloud Partners...) = 0.8366
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA GB300 NVL72...) = 0.5649
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA GB200 NVL72...) = 0.5649
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA-Certified Systems...) = 0.7078
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA Blackwell Architecture...) = 0.6997
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA Hopper Architecture...) = 0.5812
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA Ada Lovelace Architectu...) = 0.555
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA Data Center Corporate B...) = 0.616
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA Data Center Technical B...) = 0.7699
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA AI Enterprise...) = 0.9547
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA NGC...) = 0.2432
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA® accelerated computing ...) = 0.8104
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA Quantum InfiniBand...) = 0.4727
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA Spectrum™-X Ethernet...) = 0.5985
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA NGC™...) = 0.3951
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA-Certified Systems for E...) = 0.7581
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA DGX Platform...) = 0.6759
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA HGX Platform...) = 0.914
# Sim(NVIDIA AI Enterprise Platform..., NVIDIA Foundation...) = 0.5903
# Sim(NVIDIA Run:ai..., AI WorkbenchSimplify AI develo...) = 0.7932
# Sim(NVIDIA Run:ai..., API CatalogExplore NVIDIA's AI...) = 0.7481
# Sim(NVIDIA Run:ai..., NsightExplore NVIDIA developer...) = 0.7583
# Sim(NVIDIA Run:ai..., NVIDIA App for LaptopsOptimize...) = 0.5572
# Sim(NVIDIA Run:ai..., NVIDIA NGCAccelerate AI and HP...) = 0.6748
# Sim(NVIDIA Run:ai..., OverviewPowering AI, HPC, and ...) = 0.7347
# Sim(NVIDIA Run:ai..., VirtualizationNVIDIA virtual G...) = 0.5291
# Sim(NVIDIA Run:ai..., NVIDIA Cloud Partners...) = 0.4997
# Sim(NVIDIA Run:ai..., NVIDIA GB300 NVL72...) = 0.6268
# Sim(NVIDIA Run:ai..., NVIDIA GB200 NVL72...) = 0.6268
# Sim(NVIDIA Run:ai..., NVIDIA-Certified Systems...) = 0.5415
# Sim(NVIDIA Run:ai..., NVIDIA Blackwell Architecture...) = 0.5088
# Sim(NVIDIA Run:ai..., NVIDIA Hopper Architecture...) = 0.3978
# Sim(NVIDIA Run:ai..., NVIDIA Ada Lovelace Architectu...) = 0.4644
# Sim(NVIDIA Run:ai..., NVIDIA Data Center Corporate B...) = 0.5405
# Sim(NVIDIA Run:ai..., NVIDIA Data Center Technical B...) = 0.5266
# Sim(NVIDIA Run:ai..., NVIDIA AI Enterprise...) = 0.78
# Sim(NVIDIA Run:ai..., NVIDIA NGC...) = 0.3133
# Sim(NVIDIA Run:ai..., NVIDIA® accelerated computing ...) = 0.407
# Sim(NVIDIA Run:ai..., NVIDIA Quantum InfiniBand...) = 0.3825
# Sim(NVIDIA Run:ai..., NVIDIA Spectrum™-X Ethernet...) = 0.4834
# Sim(NVIDIA Run:ai..., NVIDIA NGC™...) = 0.334
# Sim(NVIDIA Run:ai..., NVIDIA-Certified Systems for E...) = 0.5149
# Sim(NVIDIA Run:ai..., NVIDIA DGX Platform...) = 0.3349
# Sim(NVIDIA Run:ai..., NVIDIA HGX Platform...) = 0.5279
# Sim(NVIDIA Run:ai..., NVIDIA Foundation...) = 0.5966
# Sim(AI WorkbenchSimplify AI develo..., API CatalogExplore NVIDIA's AI...) = 0.7692
# Sim(AI WorkbenchSimplify AI develo..., NsightExplore NVIDIA developer...) = 0.7646
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA App for LaptopsOptimize...) = 0.5408
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA NGCAccelerate AI and HP...) = 0.7318
# Sim(AI WorkbenchSimplify AI develo..., OverviewPowering AI, HPC, and ...) = 0.7859
# Sim(AI WorkbenchSimplify AI develo..., VirtualizationNVIDIA virtual G...) = 0.5613
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA Cloud Partners...) = 0.5096
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA GB300 NVL72...) = 0.4932
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA GB200 NVL72...) = 0.4932
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA-Certified Systems...) = 0.4817
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA Blackwell Architecture...) = 0.4886
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA Hopper Architecture...) = 0.4378
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA Ada Lovelace Architectu...) = 0.4123
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA Data Center Corporate B...) = 0.5745
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA Data Center Technical B...) = 0.5723
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA AI Enterprise...) = 0.7937
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA NGC...) = 0.2342
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA® accelerated computing ...) = 0.5022
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA Quantum InfiniBand...) = 0.359
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA Spectrum™-X Ethernet...) = 0.4926
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA NGC™...) = 0.3076
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA-Certified Systems for E...) = 0.5014
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA DGX Platform...) = 0.3304
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA HGX Platform...) = 0.5058
# Sim(AI WorkbenchSimplify AI develo..., NVIDIA Foundation...) = 0.5888
# Sim(API CatalogExplore NVIDIA's AI..., NsightExplore NVIDIA developer...) = 0.8899
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA App for LaptopsOptimize...) = 0.748
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA NGCAccelerate AI and HP...) = 0.8065
# Sim(API CatalogExplore NVIDIA's AI..., OverviewPowering AI, HPC, and ...) = 0.8263
# Sim(API CatalogExplore NVIDIA's AI..., VirtualizationNVIDIA virtual G...) = 0.7216
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA Cloud Partners...) = 0.6847
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA GB300 NVL72...) = 0.4873
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA GB200 NVL72...) = 0.4873
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA-Certified Systems...) = 0.69
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA Blackwell Architecture...) = 0.6538
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA Hopper Architecture...) = 0.5417
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA Ada Lovelace Architectu...) = 0.51
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA Data Center Corporate B...) = 0.75
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA Data Center Technical B...) = 0.7698
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA AI Enterprise...) = 0.8046
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA NGC...) = 0.1817
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA® accelerated computing ...) = 0.7365
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA Quantum InfiniBand...) = 0.432
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA Spectrum™-X Ethernet...) = 0.6275
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA NGC™...) = 0.328
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA-Certified Systems for E...) = 0.7702
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA DGX Platform...) = 0.4254
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA HGX Platform...) = 0.6651
# Sim(API CatalogExplore NVIDIA's AI..., NVIDIA Foundation...) = 0.6217
# Sim(NsightExplore NVIDIA developer..., NVIDIA App for LaptopsOptimize...) = 0.6885
# Sim(NsightExplore NVIDIA developer..., NVIDIA NGCAccelerate AI and HP...) = 0.8044
# Sim(NsightExplore NVIDIA developer..., OverviewPowering AI, HPC, and ...) = 0.8786
# Sim(NsightExplore NVIDIA developer..., VirtualizationNVIDIA virtual G...) = 0.6132
# Sim(NsightExplore NVIDIA developer..., NVIDIA Cloud Partners...) = 0.6081
# Sim(NsightExplore NVIDIA developer..., NVIDIA GB300 NVL72...) = 0.521
# Sim(NsightExplore NVIDIA developer..., NVIDIA GB200 NVL72...) = 0.521
# Sim(NsightExplore NVIDIA developer..., NVIDIA-Certified Systems...) = 0.6196
# Sim(NsightExplore NVIDIA developer..., NVIDIA Blackwell Architecture...) = 0.5785
# Sim(NsightExplore NVIDIA developer..., NVIDIA Hopper Architecture...) = 0.4456
# Sim(NsightExplore NVIDIA developer..., NVIDIA Ada Lovelace Architectu...) = 0.4858
# Sim(NsightExplore NVIDIA developer..., NVIDIA Data Center Corporate B...) = 0.6856
# Sim(NsightExplore NVIDIA developer..., NVIDIA Data Center Technical B...) = 0.6775
# Sim(NsightExplore NVIDIA developer..., NVIDIA AI Enterprise...) = 0.7723
# Sim(NsightExplore NVIDIA developer..., NVIDIA NGC...) = 0.2486
# Sim(NsightExplore NVIDIA developer..., NVIDIA® accelerated computing ...) = 0.5767
# Sim(NsightExplore NVIDIA developer..., NVIDIA Quantum InfiniBand...) = 0.3998
# Sim(NsightExplore NVIDIA developer..., NVIDIA Spectrum™-X Ethernet...) = 0.5094
# Sim(NsightExplore NVIDIA developer..., NVIDIA NGC™...) = 0.3354
# Sim(NsightExplore NVIDIA developer..., NVIDIA-Certified Systems for E...) = 0.6915
# Sim(NsightExplore NVIDIA developer..., NVIDIA DGX Platform...) = 0.4087
# Sim(NsightExplore NVIDIA developer..., NVIDIA HGX Platform...) = 0.6028
# Sim(NsightExplore NVIDIA developer..., NVIDIA Foundation...) = 0.6102
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA NGCAccelerate AI and HP...) = 0.8384
# Sim(NVIDIA App for LaptopsOptimize..., OverviewPowering AI, HPC, and ...) = 0.5661
# Sim(NVIDIA App for LaptopsOptimize..., VirtualizationNVIDIA virtual G...) = 0.7895
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA Cloud Partners...) = 0.762
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA GB300 NVL72...) = 0.6675
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA GB200 NVL72...) = 0.6675
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA-Certified Systems...) = 0.6946
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA Blackwell Architecture...) = 0.7287
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA Hopper Architecture...) = 0.627
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA Ada Lovelace Architectu...) = 0.6095
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA Data Center Corporate B...) = 0.6797
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA Data Center Technical B...) = 0.7641
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA AI Enterprise...) = 0.7745
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA NGC...) = 0.3408
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA® accelerated computing ...) = 0.7697
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA Quantum InfiniBand...) = 0.5246
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA Spectrum™-X Ethernet...) = 0.6843
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA NGC™...) = 0.4664
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA-Certified Systems for E...) = 0.803
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA DGX Platform...) = 0.6315
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA HGX Platform...) = 0.8495
# Sim(NVIDIA App for LaptopsOptimize..., NVIDIA Foundation...) = 0.673
# Sim(NVIDIA NGCAccelerate AI and HP..., OverviewPowering AI, HPC, and ...) = 0.8209
# Sim(NVIDIA NGCAccelerate AI and HP..., VirtualizationNVIDIA virtual G...) = 0.7868
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA Cloud Partners...) = 0.7772
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA GB300 NVL72...) = 0.7002
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA GB200 NVL72...) = 0.7002
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA-Certified Systems...) = 0.6839
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA Blackwell Architecture...) = 0.7154
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA Hopper Architecture...) = 0.6355
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA Ada Lovelace Architectu...) = 0.5892
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA Data Center Corporate B...) = 0.6803
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA Data Center Technical B...) = 0.7631
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA AI Enterprise...) = 0.8748
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA NGC...) = 0.357
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA® accelerated computing ...) = 0.7689
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA Quantum InfiniBand...) = 0.553
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA Spectrum™-X Ethernet...) = 0.6893
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA NGC™...) = 0.476
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA-Certified Systems for E...) = 0.7243
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA DGX Platform...) = 0.6572
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA HGX Platform...) = 0.8497
# Sim(NVIDIA NGCAccelerate AI and HP..., NVIDIA Foundation...) = 0.7187
# Sim(OverviewPowering AI, HPC, and ..., VirtualizationNVIDIA virtual G...) = 0.5717
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA Cloud Partners...) = 0.5108
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA GB300 NVL72...) = 0.448
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA GB200 NVL72...) = 0.448
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA-Certified Systems...) = 0.4659
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA Blackwell Architecture...) = 0.4778
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA Hopper Architecture...) = 0.4022
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA Ada Lovelace Architectu...) = 0.3816
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA Data Center Corporate B...) = 0.6027
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA Data Center Technical B...) = 0.5902
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA AI Enterprise...) = 0.7037
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA NGC...) = 0.2168
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA® accelerated computing ...) = 0.5069
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA Quantum InfiniBand...) = 0.3223
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA Spectrum™-X Ethernet...) = 0.4796
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA NGC™...) = 0.2998
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA-Certified Systems for E...) = 0.521
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA DGX Platform...) = 0.3445
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA HGX Platform...) = 0.4952
# Sim(OverviewPowering AI, HPC, and ..., NVIDIA Foundation...) = 0.5557
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA Cloud Partners...) = 0.656
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA GB300 NVL72...) = 0.5672
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA GB200 NVL72...) = 0.5672
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA-Certified Systems...) = 0.6515
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA Blackwell Architecture...) = 0.6631
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA Hopper Architecture...) = 0.6295
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA Ada Lovelace Architectu...) = 0.563
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA Data Center Corporate B...) = 0.6025
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA Data Center Technical B...) = 0.6784
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA AI Enterprise...) = 0.6805
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA NGC...) = 0.2827
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA® accelerated computing ...) = 0.7528
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA Quantum InfiniBand...) = 0.4995
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA Spectrum™-X Ethernet...) = 0.7197
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA NGC™...) = 0.4212
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA-Certified Systems for E...) = 0.6756
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA DGX Platform...) = 0.4969
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA HGX Platform...) = 0.698
# Sim(VirtualizationNVIDIA virtual G..., NVIDIA Foundation...) = 0.5778
# Sim(NVIDIA Cloud Partners..., NVIDIA GB300 NVL72...) = 0.6341
# Sim(NVIDIA Cloud Partners..., NVIDIA GB200 NVL72...) = 0.6341
# Sim(NVIDIA Cloud Partners..., NVIDIA-Certified Systems...) = 0.6748
# Sim(NVIDIA Cloud Partners..., NVIDIA Blackwell Architecture...) = 0.6935
# Sim(NVIDIA Cloud Partners..., NVIDIA Hopper Architecture...) = 0.5796
# Sim(NVIDIA Cloud Partners..., NVIDIA Ada Lovelace Architectu...) = 0.5941
# Sim(NVIDIA Cloud Partners..., NVIDIA Data Center Corporate B...) = 0.6856
# Sim(NVIDIA Cloud Partners..., NVIDIA Data Center Technical B...) = 0.7583
# Sim(NVIDIA Cloud Partners..., NVIDIA AI Enterprise...) = 0.7898
# Sim(NVIDIA Cloud Partners..., NVIDIA NGC...) = 0.3002
# Sim(NVIDIA Cloud Partners..., NVIDIA® accelerated computing ...) = 0.7996
# Sim(NVIDIA Cloud Partners..., NVIDIA Quantum InfiniBand...) = 0.539
# Sim(NVIDIA Cloud Partners..., NVIDIA Spectrum™-X Ethernet...) = 0.6285
# Sim(NVIDIA Cloud Partners..., NVIDIA NGC™...) = 0.4444
# Sim(NVIDIA Cloud Partners..., NVIDIA-Certified Systems for E...) = 0.7237
# Sim(NVIDIA Cloud Partners..., NVIDIA DGX Platform...) = 0.6924
# Sim(NVIDIA Cloud Partners..., NVIDIA HGX Platform...) = 0.8844
# Sim(NVIDIA Cloud Partners..., NVIDIA Foundation...) = 0.6724
# Sim(NVIDIA GB300 NVL72..., NVIDIA GB200 NVL72...) = 1.0
# Sim(NVIDIA GB300 NVL72..., NVIDIA-Certified Systems...) = 0.6364
# Sim(NVIDIA GB300 NVL72..., NVIDIA Blackwell Architecture...) = 0.6924
# Sim(NVIDIA GB300 NVL72..., NVIDIA Hopper Architecture...) = 0.6277
# Sim(NVIDIA GB300 NVL72..., NVIDIA Ada Lovelace Architectu...) = 0.6673
# Sim(NVIDIA GB300 NVL72..., NVIDIA Data Center Corporate B...) = 0.5306
# Sim(NVIDIA GB300 NVL72..., NVIDIA Data Center Technical B...) = 0.5394
# Sim(NVIDIA GB300 NVL72..., NVIDIA AI Enterprise...) = 0.7069
# Sim(NVIDIA GB300 NVL72..., NVIDIA NGC...) = 0.5589
# Sim(NVIDIA GB300 NVL72..., NVIDIA® accelerated computing ...) = 0.5047
# Sim(NVIDIA GB300 NVL72..., NVIDIA Quantum InfiniBand...) = 0.6806
# Sim(NVIDIA GB300 NVL72..., NVIDIA Spectrum™-X Ethernet...) = 0.5991
# Sim(NVIDIA GB300 NVL72..., NVIDIA NGC™...) = 0.5856
# Sim(NVIDIA GB300 NVL72..., NVIDIA-Certified Systems for E...) = 0.5393
# Sim(NVIDIA GB300 NVL72..., NVIDIA DGX Platform...) = 0.6403
# Sim(NVIDIA GB300 NVL72..., NVIDIA HGX Platform...) = 0.7622
# Sim(NVIDIA GB300 NVL72..., NVIDIA Foundation...) = 0.7998
# Sim(NVIDIA GB200 NVL72..., NVIDIA-Certified Systems...) = 0.6364
# Sim(NVIDIA GB200 NVL72..., NVIDIA Blackwell Architecture...) = 0.6924
# Sim(NVIDIA GB200 NVL72..., NVIDIA Hopper Architecture...) = 0.6277
# Sim(NVIDIA GB200 NVL72..., NVIDIA Ada Lovelace Architectu...) = 0.6673
# Sim(NVIDIA GB200 NVL72..., NVIDIA Data Center Corporate B...) = 0.5306
# Sim(NVIDIA GB200 NVL72..., NVIDIA Data Center Technical B...) = 0.5394
# Sim(NVIDIA GB200 NVL72..., NVIDIA AI Enterprise...) = 0.7069
# Sim(NVIDIA GB200 NVL72..., NVIDIA NGC...) = 0.5589
# Sim(NVIDIA GB200 NVL72..., NVIDIA® accelerated computing ...) = 0.5047
# Sim(NVIDIA GB200 NVL72..., NVIDIA Quantum InfiniBand...) = 0.6806
# Sim(NVIDIA GB200 NVL72..., NVIDIA Spectrum™-X Ethernet...) = 0.5991
# Sim(NVIDIA GB200 NVL72..., NVIDIA NGC™...) = 0.5856
# Sim(NVIDIA GB200 NVL72..., NVIDIA-Certified Systems for E...) = 0.5393
# Sim(NVIDIA GB200 NVL72..., NVIDIA DGX Platform...) = 0.6403
# Sim(NVIDIA GB200 NVL72..., NVIDIA HGX Platform...) = 0.7622
# Sim(NVIDIA GB200 NVL72..., NVIDIA Foundation...) = 0.7998
# Sim(NVIDIA-Certified Systems..., NVIDIA Blackwell Architecture...) = 0.7381
# Sim(NVIDIA-Certified Systems..., NVIDIA Hopper Architecture...) = 0.6138
# Sim(NVIDIA-Certified Systems..., NVIDIA Ada Lovelace Architectu...) = 0.6055
# Sim(NVIDIA-Certified Systems..., NVIDIA Data Center Corporate B...) = 0.6472
# Sim(NVIDIA-Certified Systems..., NVIDIA Data Center Technical B...) = 0.697
# Sim(NVIDIA-Certified Systems..., NVIDIA AI Enterprise...) = 0.7164
# Sim(NVIDIA-Certified Systems..., NVIDIA NGC...) = 0.2802
# Sim(NVIDIA-Certified Systems..., NVIDIA® accelerated computing ...) = 0.7179
# Sim(NVIDIA-Certified Systems..., NVIDIA Quantum InfiniBand...) = 0.5153
# Sim(NVIDIA-Certified Systems..., NVIDIA Spectrum™-X Ethernet...) = 0.5324
# Sim(NVIDIA-Certified Systems..., NVIDIA NGC™...) = 0.3781
# Sim(NVIDIA-Certified Systems..., NVIDIA-Certified Systems for E...) = 0.9009
# Sim(NVIDIA-Certified Systems..., NVIDIA DGX Platform...) = 0.5064
# Sim(NVIDIA-Certified Systems..., NVIDIA HGX Platform...) = 0.7545
# Sim(NVIDIA-Certified Systems..., NVIDIA Foundation...) = 0.6131
# Sim(NVIDIA Blackwell Architecture..., NVIDIA Hopper Architecture...) = 0.7169
# Sim(NVIDIA Blackwell Architecture..., NVIDIA Ada Lovelace Architectu...) = 0.7797
# Sim(NVIDIA Blackwell Architecture..., NVIDIA Data Center Corporate B...) = 0.5661
# Sim(NVIDIA Blackwell Architecture..., NVIDIA Data Center Technical B...) = 0.6246
# Sim(NVIDIA Blackwell Architecture..., NVIDIA AI Enterprise...) = 0.7208
# Sim(NVIDIA Blackwell Architecture..., NVIDIA NGC...) = 0.3866
# Sim(NVIDIA Blackwell Architecture..., NVIDIA® accelerated computing ...) = 0.7143
# Sim(NVIDIA Blackwell Architecture..., NVIDIA Quantum InfiniBand...) = 0.6015
# Sim(NVIDIA Blackwell Architecture..., NVIDIA Spectrum™-X Ethernet...) = 0.6065
# Sim(NVIDIA Blackwell Architecture..., NVIDIA NGC™...) = 0.4989
# Sim(NVIDIA Blackwell Architecture..., NVIDIA-Certified Systems for E...) = 0.6937
# Sim(NVIDIA Blackwell Architecture..., NVIDIA DGX Platform...) = 0.6447
# Sim(NVIDIA Blackwell Architecture..., NVIDIA HGX Platform...) = 0.7726
# Sim(NVIDIA Blackwell Architecture..., NVIDIA Foundation...) = 0.6139
# Sim(NVIDIA Hopper Architecture..., NVIDIA Ada Lovelace Architectu...) = 0.6346
# Sim(NVIDIA Hopper Architecture..., NVIDIA Data Center Corporate B...) = 0.4435
# Sim(NVIDIA Hopper Architecture..., NVIDIA Data Center Technical B...) = 0.5148
# Sim(NVIDIA Hopper Architecture..., NVIDIA AI Enterprise...) = 0.6076
# Sim(NVIDIA Hopper Architecture..., NVIDIA NGC...) = 0.3106
# Sim(NVIDIA Hopper Architecture..., NVIDIA® accelerated computing ...) = 0.6343
# Sim(NVIDIA Hopper Architecture..., NVIDIA Quantum InfiniBand...) = 0.533
# Sim(NVIDIA Hopper Architecture..., NVIDIA Spectrum™-X Ethernet...) = 0.5507
# Sim(NVIDIA Hopper Architecture..., NVIDIA NGC™...) = 0.405
# Sim(NVIDIA Hopper Architecture..., NVIDIA-Certified Systems for E...) = 0.5544
# Sim(NVIDIA Hopper Architecture..., NVIDIA DGX Platform...) = 0.5886
# Sim(NVIDIA Hopper Architecture..., NVIDIA HGX Platform...) = 0.6658
# Sim(NVIDIA Hopper Architecture..., NVIDIA Foundation...) = 0.5673
# Sim(NVIDIA Ada Lovelace Architectu..., NVIDIA Data Center Corporate B...) = 0.4637
# Sim(NVIDIA Ada Lovelace Architectu..., NVIDIA Data Center Technical B...) = 0.5002
# Sim(NVIDIA Ada Lovelace Architectu..., NVIDIA AI Enterprise...) = 0.6093
# Sim(NVIDIA Ada Lovelace Architectu..., NVIDIA NGC...) = 0.325
# Sim(NVIDIA Ada Lovelace Architectu..., NVIDIA® accelerated computing ...) = 0.5367
# Sim(NVIDIA Ada Lovelace Architectu..., NVIDIA Quantum InfiniBand...) = 0.5321
# Sim(NVIDIA Ada Lovelace Architectu..., NVIDIA Spectrum™-X Ethernet...) = 0.4947
# Sim(NVIDIA Ada Lovelace Architectu..., NVIDIA NGC™...) = 0.381
# Sim(NVIDIA Ada Lovelace Architectu..., NVIDIA-Certified Systems for E...) = 0.5422
# Sim(NVIDIA Ada Lovelace Architectu..., NVIDIA DGX Platform...) = 0.5645
# Sim(NVIDIA Ada Lovelace Architectu..., NVIDIA HGX Platform...) = 0.6446
# Sim(NVIDIA Ada Lovelace Architectu..., NVIDIA Foundation...) = 0.5561
# Sim(NVIDIA Data Center Corporate B..., NVIDIA Data Center Technical B...) = 0.9327
# Sim(NVIDIA Data Center Corporate B..., NVIDIA AI Enterprise...) = 0.6247
# Sim(NVIDIA Data Center Corporate B..., NVIDIA NGC...) = 0.2134
# Sim(NVIDIA Data Center Corporate B..., NVIDIA® accelerated computing ...) = 0.6973
# Sim(NVIDIA Data Center Corporate B..., NVIDIA Quantum InfiniBand...) = 0.4602
# Sim(NVIDIA Data Center Corporate B..., NVIDIA Spectrum™-X Ethernet...) = 0.6114
# Sim(NVIDIA Data Center Corporate B..., NVIDIA NGC™...) = 0.3434
# Sim(NVIDIA Data Center Corporate B..., NVIDIA-Certified Systems for E...) = 0.7114
# Sim(NVIDIA Data Center Corporate B..., NVIDIA DGX Platform...) = 0.4161
# Sim(NVIDIA Data Center Corporate B..., NVIDIA HGX Platform...) = 0.6396
# Sim(NVIDIA Data Center Corporate B..., NVIDIA Foundation...) = 0.6518
# Sim(NVIDIA Data Center Technical B..., NVIDIA AI Enterprise...) = 0.7273
# Sim(NVIDIA Data Center Technical B..., NVIDIA NGC...) = 0.2063
# Sim(NVIDIA Data Center Technical B..., NVIDIA® accelerated computing ...) = 0.8102
# Sim(NVIDIA Data Center Technical B..., NVIDIA Quantum InfiniBand...) = 0.5284
# Sim(NVIDIA Data Center Technical B..., NVIDIA Spectrum™-X Ethernet...) = 0.6734
# Sim(NVIDIA Data Center Technical B..., NVIDIA NGC™...) = 0.3664
# Sim(NVIDIA Data Center Technical B..., NVIDIA-Certified Systems for E...) = 0.7605
# Sim(NVIDIA Data Center Technical B..., NVIDIA DGX Platform...) = 0.5369
# Sim(NVIDIA Data Center Technical B..., NVIDIA HGX Platform...) = 0.7837
# Sim(NVIDIA Data Center Technical B..., NVIDIA Foundation...) = 0.6239
# Sim(NVIDIA AI Enterprise..., NVIDIA NGC...) = 0.3373
# Sim(NVIDIA AI Enterprise..., NVIDIA® accelerated computing ...) = 0.7246
# Sim(NVIDIA AI Enterprise..., NVIDIA Quantum InfiniBand...) = 0.5238
# Sim(NVIDIA AI Enterprise..., NVIDIA Spectrum™-X Ethernet...) = 0.6153
# Sim(NVIDIA AI Enterprise..., NVIDIA NGC™...) = 0.4522
# Sim(NVIDIA AI Enterprise..., NVIDIA-Certified Systems for E...) = 0.7212
# Sim(NVIDIA AI Enterprise..., NVIDIA DGX Platform...) = 0.6504
# Sim(NVIDIA AI Enterprise..., NVIDIA HGX Platform...) = 0.8731
# Sim(NVIDIA AI Enterprise..., NVIDIA Foundation...) = 0.6856
# Sim(NVIDIA NGC..., NVIDIA® accelerated computing ...) = 0.1912
# Sim(NVIDIA NGC..., NVIDIA Quantum InfiniBand...) = 0.3738
# Sim(NVIDIA NGC..., NVIDIA Spectrum™-X Ethernet...) = 0.3048
# Sim(NVIDIA NGC..., NVIDIA NGC™...) = 0.9058
# Sim(NVIDIA NGC..., NVIDIA-Certified Systems for E...) = 0.225
# Sim(NVIDIA NGC..., NVIDIA DGX Platform...) = 0.4087
# Sim(NVIDIA NGC..., NVIDIA HGX Platform...) = 0.3729
# Sim(NVIDIA NGC..., NVIDIA Foundation...) = 0.424
# Sim(NVIDIA® accelerated computing ..., NVIDIA Quantum InfiniBand...) = 0.5119
# Sim(NVIDIA® accelerated computing ..., NVIDIA Spectrum™-X Ethernet...) = 0.7592
# Sim(NVIDIA® accelerated computing ..., NVIDIA NGC™...) = 0.4596
# Sim(NVIDIA® accelerated computing ..., NVIDIA-Certified Systems for E...) = 0.783
# Sim(NVIDIA® accelerated computing ..., NVIDIA DGX Platform...) = 0.6143
# Sim(NVIDIA® accelerated computing ..., NVIDIA HGX Platform...) = 0.8344
# Sim(NVIDIA® accelerated computing ..., NVIDIA Foundation...) = 0.571
# Sim(NVIDIA Quantum InfiniBand..., NVIDIA Spectrum™-X Ethernet...) = 0.5815
# Sim(NVIDIA Quantum InfiniBand..., NVIDIA NGC™...) = 0.4442
# Sim(NVIDIA Quantum InfiniBand..., NVIDIA-Certified Systems for E...) = 0.4396
# Sim(NVIDIA Quantum InfiniBand..., NVIDIA DGX Platform...) = 0.5324
# Sim(NVIDIA Quantum InfiniBand..., NVIDIA HGX Platform...) = 0.6184
# Sim(NVIDIA Quantum InfiniBand..., NVIDIA Foundation...) = 0.5252
# Sim(NVIDIA Spectrum™-X Ethernet..., NVIDIA NGC™...) = 0.5275
# Sim(NVIDIA Spectrum™-X Ethernet..., NVIDIA-Certified Systems for E...) = 0.5571
# Sim(NVIDIA Spectrum™-X Ethernet..., NVIDIA DGX Platform...) = 0.5023
# Sim(NVIDIA Spectrum™-X Ethernet..., NVIDIA HGX Platform...) = 0.667
# Sim(NVIDIA Spectrum™-X Ethernet..., NVIDIA Foundation...) = 0.5683
# Sim(NVIDIA NGC™..., NVIDIA-Certified Systems for E...) = 0.3465
# Sim(NVIDIA NGC™..., NVIDIA DGX Platform...) = 0.4997
# Sim(NVIDIA NGC™..., NVIDIA HGX Platform...) = 0.51
# Sim(NVIDIA NGC™..., NVIDIA Foundation...) = 0.4562
# Sim(NVIDIA-Certified Systems for E..., NVIDIA DGX Platform...) = 0.5006
# Sim(NVIDIA-Certified Systems for E..., NVIDIA HGX Platform...) = 0.771
# Sim(NVIDIA-Certified Systems for E..., NVIDIA Foundation...) = 0.6111
# Sim(NVIDIA DGX Platform..., NVIDIA HGX Platform...) = 0.7852
# Sim(NVIDIA DGX Platform..., NVIDIA Foundation...) = 0.5311
# Sim(NVIDIA HGX Platform..., NVIDIA Foundation...) = 0.6987

# %% [markdown]
# ---
#
# ## README — How to Use & Extend
#
# **What this notebook does**
# 1. Pulls (or falls back to) NVIDIA product text and runs it through two spaCy models:
#    - `en_core_web_trf` (Transformer-based; higher accuracy, slower)
#    - `en_core_web_md` (Faster; includes word vectors)
# 2. Compares **entities** (NER) and **similarity** to the concept “GPU” across texts.
# 3. Benchmarks **inference speed**.
# 4. Visualizes a **dependency parse**.
# 5. Provides an optional **similarity clustering** demo using vectors.
#
# **When to use which model?**
# - Use **TRF** when accuracy matters most and throughput is acceptable.
# - Use **MD** for lower latency and simpler similarity operations using static vectors.
#
# **Extending this notebook**
# - Add an **EntityRuler** with more patterns or train a **custom NER** on your labeled NVIDIA catalog.
# - Use **SentenceTransformers** for stronger semantic embeddings and cluster with **FAISS**.
# - For production, precompute vectors, cache results, and batch with `nlp.pipe`.
#
# **Troubleshooting**
# - If installs fail, run the notebook in an environment with `pip` enabled.
# - If model downloads fail, manually install models or use already-packaged models in your environment.
# - Some environments restrict network calls; rely on the built‑in fallback list.
#
# ---
